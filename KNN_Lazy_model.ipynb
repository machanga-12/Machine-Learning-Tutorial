# %% [markdown]
# ### KNN Model
# ### Scikit-Lean Daibetes Dataset
# ### Gaol: To predict diabetes progression based on various health measurements

# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_diabetes
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error

# %%
# Load the dataset
diabetes = load_diabetes()
data = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
data['target'] = diabetes.target

# %%
print(data.head())
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
# Visualize the dataset
plt.figure(figsize=(10, 6))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=data['target'], cmap='viridis')
plt.xlabel('Age')
plt.ylabel('Sex')
plt.title('Diabetes Data Visualization (First Two Features)')
plt.show()

# %%
X = data.iloc[:, :-1]
y = data['target']

# %%
# Train - test - split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Train the KNN Model
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)
print("\nMean Squared Error:")
print(mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error:
# 7923.067669172932

# %%
# Add new data
new_data = pd.DataFrame([[0.05, 0.05, 0.1, 0.0, 0.1, -0.1, -0.05, 0.03, 0.04, 0.02],
                         [0.07, -0.02, 0.12, 0.03, 0.14, -0.07, -0.03, 0.01, 0.06, 0.05]],
                        columns=diabetes.feature_names)
                         
predictions = knn.predict(new_data)
print(predictions)
# Out:
# [150. 220.]
